# %%
from fastbook import *
from fastai.vision.widgets import *
from PIL import Image

# %%
from fastai.basics import load_learner

# %%
import fastai
fastai.__version__
# Out:
# '2.1.8'

# %%
key = os.environ.get('AZURE_SEARCH_KEY', '73054b9ab75e462e81e11f32920fa489')

# %%
if not path.exists():
    print('yes')
    o = "rusted"
    path.mkdir()
    dest = path
    results = search_images_bing(key, f'{o}', max_images=300)
    download_images(dest, urls=results.attrgot('contentUrl'))
# Out:
# yes

# %%
path
# Out:
# Path('CorrosionImages')

# %%
import os 
import glob

# %%
imgs = glob.glob('CorrosionImages/*jpeg')
for i, img in enumerate(imgs):
    os.rename(img,f'CorrosionImages/img{i}.jpeg')

# %%
pngs = glob.glob('CorrosionImages/*webp')
for i, img in enumerate(pngs):
    img = Image.open(img).convert('RGB')
    img.save(f'CorrosionImages/png{i}.jpg')

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=845x321 at 0x7F9B05D70210>
